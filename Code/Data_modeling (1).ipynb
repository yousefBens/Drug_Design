# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# %%
df = pd.read_csv('/content/discriptors_filtred_class_pIC50.csv')

# %%
X = df.drop('pIC50', axis=1)
X = X.drop('bioactivity_class', axis=1)
X

# %%
Y = df.pIC50
Y

# %%
X.shape

# %%
Y.shape

# %%
import numpy as np

# %%
type(Y)

# %%
Y.shape

# %%
from sklearn.feature_selection import VarianceThreshold
selection = VarianceThreshold(threshold=(.8 * (1 - .8)))    
X = selection.fit_transform(X)

# %%
X.shape

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)

# %%
type(X_test)

# %%
X_train.shape, Y_train.shape

# %%
X_test.shape, Y_test.shape

# %%
model = RandomForestRegressor(n_estimators=100)
model.fit(X_train, Y_train)
r2 = model.score(X_test, Y_test)
r2

# %%
Y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(color_codes=True)
sns.set_style("white")

ax = sns.regplot(x = Y_test, y = Y_pred, scatter_kws={'alpha':0.4})
ax.set_xlabel('Experimental pIC50', fontsize='large', fontweight='bold')
ax.set_ylabel('Predicted pIC50', fontsize='large', fontweight='bold')
ax.set_xlim(0, 12)
ax.set_ylim(0, 12)
ax.figure.set_size_inches(5, 5)
plt.show

# %%
! pip install lazypredict

# %%
import lazypredict
from lazypredict.Supervised import LazyRegressor

# %%
# Defines and builds the lazyclassifier
clf = LazyRegressor(verbose=0,ignore_warnings=True, custom_metric=None)
models_train,predictions_train = clf.fit(X_train, X_train, Y_train, Y_train)
models_test,predictions_test = clf.fit(X_train, X_test, Y_train, Y_test)
# Out:
# 100%|██████████| 42/42 [14:04<00:00, 20.10s/it]
# 'tuple' object has no attribute '__name__'
# Invalid Regressor(s)
# 100%|██████████| 42/42 [13:34<00:00, 19.39s/it]

# %%
# Performance table of the training set (80% subset)
type(predictions_train)
# Out:
# pandas.core.frame.DataFrame

# %%
import matplotlib.pyplot as plt

# %%
# !pip install dataframe-image
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting dataframe-image
#   Downloading dataframe_image-0.1.11-py3-none-any.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 48.0 MB/s eta 0:00:00
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from dataframe-image) (8.4.0)
# Collecting html2image
#   Downloading html2image-2.0.3-py3-none-any.whl (18 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from dataframe-image) (2.27.1)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from dataframe-image) (1.5.3)
# Collecting cssutils
#   Downloading cssutils-2.6.0-py3-none-any.whl (399 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 399.7/399.7 kB 29.2 MB/s eta 0:00:00
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from dataframe-image) (4.9.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from dataframe-image) (23.1)
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 43.2 MB/s eta 0:00:00
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.10/dist-packages (from dataframe-image) (6.5.4)
# Requirement already satisfied: mistune in /usr/local/lib/python3.10/dist-packages (from dataframe-image) (0.8.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from dataframe-image) (4.11.2)
# Requirement already satisfied: jinja2>=3.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->dataframe-image) (3.1.2)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->dataframe-image) (0.7.1)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->dataframe-image) (0.7.4)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->dataframe-image) (6.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->dataframe-image) (2.1.2)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->dataframe-image) (0.2.2)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->dataframe-image) (1.2.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->dataframe-image) (0.4)
# Requirement already satisfied: pygments>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->dataframe-image) (2.14.0)
# Requirement already satisfied: jupyter-core>=4.7 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->dataframe-image) (5.3.0)
# Requirement already satisfied: traitlets>=5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->dataframe-image) (5.7.1)
# Requirement already satisfied: nbformat>=5.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->dataframe-image) (5.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->dataframe-image) (1.5.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->dataframe-image) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->dataframe-image) (1.22.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->dataframe-image) (2022.7.1)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->dataframe-image) (2.0.12)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 10.4 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 14.2 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->dataframe-image) (23.1.0)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 22.2 MB/s eta 0:00:00
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->dataframe-image) (2.4.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->dataframe-image) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->dataframe-image) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->dataframe-image) (1.26.15)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.7->nbconvert>=5->dataframe-image) (3.3.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.10/dist-packages (from nbclient>=0.5.0->nbconvert>=5->dataframe-image) (6.1.12)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat>=5.1->nbconvert>=5->dataframe-image) (4.3.3)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat>=5.1->nbconvert>=5->dataframe-image) (2.16.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=0.24->dataframe-image) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert>=5->dataframe-image) (0.5.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert>=5->dataframe-image) (0.19.3)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.10/dist-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert>=5->dataframe-image) (23.2.1)
# Requirement already satisfied: tornado>=4.1 in /usr/local/lib/python3.10/dist-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert>=5->dataframe-image) (6.2)
# Installing collected packages: multidict, html2image, frozenlist, cssutils, async-timeout, yarl, aiosignal, aiohttp, dataframe-image
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 cssutils-2.6.0 dataframe-image-0.1.11 frozenlist-1.3.3 html2image-2.0.3 multidict-6.0.4 yarl-1.9.2

# %%
import dataframe_image as dfi

# %%
predictions_train
# Out:
#                                          Adjusted R-Squared  \
# Model
# DecisionTreeRegressor                                  0.89
# ExtraTreeRegressor                                     0.89
# ExtraTreesRegressor                                    0.89
# GaussianProcessRegressor                               0.89
# XGBRegressor                                           0.86
# RandomForestRegressor                                  0.85
# BaggingRegressor                                       0.82
# MLPRegressor                                           0.81
# HistGradientBoostingRegressor                          0.70
# LGBMRegressor                                          0.69
# KNeighborsRegressor                                    0.61
# SVR                                                    0.55
# NuSVR                                                  0.54
# GradientBoostingRegressor                              0.43
# Ridge                                                  0.29
# LinearRegression                                       0.29
# TransformedTargetRegressor                             0.29
# LassoCV                                                0.29
# ElasticNetCV                                           0.29
# RidgeCV                                                0.29
# HuberRegressor                                         0.27
# LassoLarsIC                                            0.26
# BayesianRidge                                          0.26
# LassoLarsCV                                            0.25
# LinearSVR                                              0.25
# SGDRegressor                                           0.23
# PoissonRegressor                                       0.22
# AdaBoostRegressor                                      0.18
# GammaRegressor                                         0.17
# TweedieRegressor                                       0.17
# OrthogonalMatchingPursuitCV                            0.16
# OrthogonalMatchingPursuit                              0.16
# LarsCV                                                 0.11
# PassiveAggressiveRegressor                            -0.02
# LassoLars                                             -0.05
# Lasso                                                 -0.05
# ElasticNet                                            -0.05
# DummyRegressor                                        -0.05
# QuantileRegressor                                     -0.06
# KernelRidge                                          -16.20
# Lars                                               -3000.02
# RANSACRegressor               -6174329393278492474343424.00
#
#                                                   R-Squared             RMSE  \
# Model
# DecisionTreeRegressor                                  0.90             0.45
# ExtraTreeRegressor                                     0.90             0.45
# ExtraTreesRegressor                                    0.90             0.45
# GaussianProcessRegressor                               0.90             0.45
# XGBRegressor                                           0.87             0.51
# RandomForestRegressor                                  0.85             0.54
# BaggingRegressor                                       0.83             0.58
# MLPRegressor                                           0.82             0.60
# HistGradientBoostingRegressor                          0.71             0.75
# LGBMRegressor                                          0.71             0.76
# KNeighborsRegressor                                    0.63             0.86
# SVR                                                    0.58             0.91
# NuSVR                                                  0.56             0.93
# GradientBoostingRegressor                              0.45             1.04
# Ridge                                                  0.33             1.15
# LinearRegression                                       0.33             1.15
# TransformedTargetRegressor                             0.33             1.15
# LassoCV                                                0.32             1.15
# ElasticNetCV                                           0.32             1.15
# RidgeCV                                                0.32             1.16
# HuberRegressor                                         0.31             1.17
# LassoLarsIC                                            0.30             1.17
# BayesianRidge                                          0.29             1.18
# LassoLarsCV                                            0.29             1.18
# LinearSVR                                              0.29             1.18
# SGDRegressor                                           0.26             1.20
# PoissonRegressor                                       0.26             1.21
# AdaBoostRegressor                                      0.22             1.24
# GammaRegressor                                         0.20             1.25
# TweedieRegressor                                       0.20             1.25
# OrthogonalMatchingPursuitCV                            0.20             1.25
# OrthogonalMatchingPursuit                              0.20             1.25
# LarsCV                                                 0.15             1.29
# PassiveAggressiveRegressor                             0.03             1.38
# LassoLars                                              0.00             1.40
# Lasso                                                  0.00             1.40
# ElasticNet                                             0.00             1.40
# DummyRegressor                                         0.00             1.40
# QuantileRegressor                                     -0.01             1.41
# KernelRidge                                          -15.40             5.67
# Lars                                               -2860.18            74.95
# RANSACRegressor               -5886606069808490902192128.00 3399469615296.23
#
#                                Time Taken
# Model
# DecisionTreeRegressor                0.12
# ExtraTreeRegressor                   0.15
# ExtraTreesRegressor                  5.52
# GaussianProcessRegressor             4.18
# XGBRegressor                         3.59
# RandomForestRegressor                3.51
# BaggingRegressor                     0.45
# MLPRegressor                         6.28
# HistGradientBoostingRegressor        1.39
# LGBMRegressor                        0.37
# KNeighborsRegressor                  0.17
# SVR                                  2.35
# NuSVR                                3.15
# GradientBoostingRegressor            1.39
# Ridge                                0.05
# LinearRegression                     0.13
# TransformedTargetRegressor           0.07
# LassoCV                              5.37
# ElasticNetCV                         4.33
# RidgeCV                              0.11
# HuberRegressor                       0.29
# LassoLarsIC                          0.17
# BayesianRidge                        0.18
# LassoLarsCV                          0.31
# LinearSVR                            0.66
# SGDRegressor                         0.14
# PoissonRegressor                     0.17
# AdaBoostRegressor                    0.82
# GammaRegressor                       0.09
# TweedieRegressor                     0.26
# OrthogonalMatchingPursuitCV          0.15
# OrthogonalMatchingPursuit            0.07
# LarsCV                               0.82
# PassiveAggressiveRegressor           0.09
# LassoLars                            0.10
# Lasso                                0.15
# ElasticNet                           0.04
# DummyRegressor                       0.03
# QuantileRegressor                  794.14
# KernelRidge                          0.80
# Lars                                 0.10
# RANSACRegressor                      1.65

# %%
import matplotlib.pyplot as plt
import pandas as pd
from pandas.plotting import table


ax = plt.subplot(111, frame_on=False) # no visible frame
ax.xaxis.set_visible(False) # hide the x axis
ax.yaxis.set_visible(False) # hide the y axis
table(ax, predictions_train, loc='center') # where df is your data frame
plt.savefig('mytablee.png')

# %%
# Bar plot of R-squared values
import matplotlib.pyplot as plt
import seaborn as sns

#train["R-Squared"] = [0 if i < 0 else i for i in train.iloc[:,0] ]

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="R-Squared", data=predictions_train)
ax.set(xlim=(0, 1))
# Out:
# [(0.0, 1.0)]

# %%
# Bar plot of RMSE values
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="RMSE", data=predictions_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]

# %%
# Bar plot of calculation time
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="Time Taken", data=predictions_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]
